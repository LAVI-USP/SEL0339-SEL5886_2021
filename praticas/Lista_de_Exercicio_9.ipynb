# %% [markdown]
# # Lista de Exercício 9
# ### Introdução à Visão Computacional (SEL0339/SEL5886)
#
# **Instruções:**
#
#  1. Esta lista consiste de 5 exercícios.
#  1. Deve-se colocar comentários nos códigos desenvolvidos.
#  1. As perguntas devem ser respondidas também como comentários no arquivo.
#  1. Colocar seu nome e número USP abaixo.
#  1. Quaisquer problemas na execução das listas, entrar em contato com os monitores.
#  1. Depois de terminado os exercícios, deve ser gerado um arquivo **extensão .ipynb** para ser enviado ao professor pelo E-DISCIPLINAS da disciplina até a data máxima de entrega.
#  1. Caso não seja enviado, o aluno ficará sem nota.
#
#
# ---
#
#
#
#  <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/LAVI-USP/SEL0339-SEL5886/blob/master/praticas/Lista_de_Exercicio_9.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Executar no Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/LAVI-USP/SEL0339-SEL5886/blob/master/praticas/Lista_de_Exercicio_9.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />Ver codigo fonte no GitHub</a>
#   </td>
# </table>

# %% [markdown]
# `Nome: `
#
# `Número USP: `

# %% [markdown]
# ### Introdução:
#
#
# Vamos importar as bibliotecas que iremos utilizar:

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

from skimage.transform import rotate
from skimage.feature import local_binary_pattern

# %% [markdown]
# #### **Atenção**: os códigos abaixo são para fazer o download das imagens (EXECUTE-OS). Os mesmos não fazem parte dessa prática.

# %%
import urllib.request

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/triangulo.png", "triangulo.png")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/estrela.png", "estrela.png")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/folha_ruim.png", "folha_ruim.png")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/guitarra.tif", "guitarra.tif")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/banjo.tif", "banjo.tif")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/tex3.tiff", "tex3.tiff")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/tex2.tiff", "tex2.tiff")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/tex1.tiff", "tex1.tiff")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/tex4.tiff", "tex4.tiff")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/circulo1.tif", "circulo1.tif")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/circulo2.tif", "circulo2.tif")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/quadrado1.tif", "quadrado1.tif")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/quadrado2.tif", "quadrado2.tif")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

# %% [markdown]
# ### 1) Momentos
#
# A equação generalizada para o cálculo do momento $m_{pq}$ é dada por:
#
# \begin{equation}
# m_{pq} = \int_{-\infty}^{\infty}\int_{-\infty}^{\infty} x^p y^q \, f(x,y) \, dx dy, \end{equation}
#
# onde $f(x,y)$ é a imagem, $x$ e $y$ suas respectivas coordenadas. Seguindo a teoria de momentos, as coordenadas do centro de massa normalizado de um objeto podem ser determinadas utilizando as seguintes equações:
#
# \begin{equation}
#   \bar{x} = \frac{m_{10}}{m_{00}}
#   \;\;\;
#   \bar{y} = \frac{m_{01}}{m_{00}}
# \end{equation}
#
# <center><figure class="half" style="display:flex">
#     <img width="256" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/triangulo.png">
#     <img width="256" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/estrela.png">
#     <figcaption><b> Figura 1: </b> Da esquerda para a direita: <i>triangulo.png</i> e <i>estrela.png</i>.</b></figcaption>
# </figure></center>
#
# **Exercício:**
#
# 1. Construa uma função chamada `momentos` que, dado uma imagem de entrada, retorne todos os momentos $m_{pq}$, com p e q variando de 0 a 1, isto é, que compute os 4 momentos: $m_{00}$, $m_{01}$, $m_{10}$ e $m_{11}$;
#
# 2. Utilizando a função `momentos` e o equacionamento descrito acima, determine as coordenadas do centro de massa dos objetos das figuras `triangulo.png` e `estrela.png`.

# %%
## -- Seu código começa AQUI -- ##

## -- Seu código termina AQUI -- ##

# %% [markdown]
# ### 2) Momentos invariantes de Hu
#
# <center><figure class="half" style="display:flex">
#     <img width="128" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/guitarra.tif">
#     <img width="128" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/banjo.png">
#     <figcaption><b> Figura 2: </b> Da esquerda para a direita: <i>guitarra.tif</i> e <i>banjo.tif</i>.</b></figcaption>
# </figure></center>
#
# **Exercício:**
#
# 1. Binarizar as imagens `guitarra.tif` e `banjo.tif`. Assegure-se que o objeto seja representado como valor alto (branco) e o fundo como valor baixo (preto).
#
# 2. Realize as seguintes operações sobre a imagem:
#
#   *   Reduzir a imagem da guitarra à quarta parte do seu tamanho original e colocar em uma imagem do mesmo tamanho;
#   *   Transladar a imagem para o centro da imagem (aproximado);
#   *   Rotacionar a imagem em $+30^{\circ}$.
#
# 3. Calcular os momentos invariantes de Hu de ambas as imagens e de suas respectivas imagens resultantes após as transformações aplicadas em (2);
#
# 4. Compare os momentos de Hu de cada imagem com as suas versões após as operações. Em seguida, compare os momentos de Hu entre as imagens da guitarra e do banjo. Calcule a distância euclidiana entre os vetores de momentos de Hu de cada imagem. Os momentos de Hu foram discriminantes? Comente.
#
# <details>
# <summary>
#     <font size="3" color="darkblue"><b>Dicas:</b></font>
# </summary>
#
# *  Você pode utilizar a função [cv.HuMoments](https://docs.opencv.org/3.4/d3/dc0/group__imgproc__shape.html#gab001db45c1f1af6cbdbe64df04c4e944) para calcular os 7 momentos invariantes de Hu. Para isso, primeiramente você precisa calcular os todos os momentos até a terceira ordem através da função [cv.moments](https://docs.opencv.org/3.4/d3/dc0/group__imgproc__shape.html#ga556a180f43cab22649c23ada36a8a139).
#
# * Você pode utilizar a função [rotate](https://scikit-image.org/docs/dev/api/skimage.transform.html#skimage.transform.rotate) da biblioteca scikit-image.
#
# *  Você pode utilizar a função [cv.threshold](https://docs.opencv.org/master/d7/d1b/group__imgproc__misc.html#gae8a4a146d1ca78c626a53577199e9c57) para a binarização com limiares pré-estabelecidos ou para o método de Otsu. Você também pode utilizar a função [threshold_otsu](https://scikit-image.org/docs/dev/api/skimage.filters.html#skimage.filters.threshold_otsu) da biblioteca `skimage` ([Exemplo](https://scikit-image.org/docs/dev/auto_examples/segmentation/plot_thresholding.html)).
#
# * Você pode utilizar a função [np.linalg.norm](https://numpy.org/doc/stable/reference/generated/numpy.linalg.norm.html) da biblioteca `numpy.linalg` para calcular a distância entre os vetores.
#
# *Ex:*
# ``` python
# moments = cv.moments(myImg)
# HuMoments = cv.HuMoments(moments)
#
# myImg_rot = rotate(myImg, angle, preserve_range=True)
#
# # Global thresholding
# ret1,th1 = cv.threshold(myImg,thresh,maxVal,cv.THRESH_BINARY_INV)
# # Otsu's thresholding
# ret2,th2 = cv.threshold(myImg,0,maxVal,cv.THRESH_BINARY_INV+cv.THRESH_OTSU)
#
# #Norma do vetor diferença entre os momentos, nesse caso, equivale à distância euclidiana
# L2_distance = np.linalg.norm(momentos_de_HU_1 - momentos_de_HU_2)
# ```

# %%
## -- Seu código começa AQUI -- ##

## -- Seu código termina AQUI -- ##

# %% [markdown]
# ### 3) Assinaturas
#
# <center><figure class="half" style="display:flex">
#     <img width="128" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/circulo1.png">
#     <img width="128" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/circulo2.png">
#     <img width="128" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/quadrado1.png">
#     <img width="128" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/quadrado2.png">
#     <figcaption><b> Figura 3: </b> Da esquerda para a direita: <i>circulo1.tif</i>, <i>circulo2.tif</i>, <i>quadrado1.tif</i> e <i>quadrado2.tif</i>.</b></figcaption>
# </figure></center>
#
# **Exercício:**
#
# 1. Utilize a função chamada `assinatura` que plota a assinatura de um contorno a partir do seu centro de massa ($\bar{x}$   e $\bar{y}$ calculados no exercício 1);
#
# 2. Aplique essa função para as imagens:
#
#   *   `circulo1.tif`
#   *   `circulo2.tif`
#   *   `quadrado1.tif`
#   *   `quadrado2.tif`
#
# 3. Compare e comente os resultados obtidos. Mostre o resultado utilizando um `subplot` de tamanho (1,2), onde o primeiro deve mostrar a imagem original e o segundo a respectiva assinatura. Além disso, coloque um '+' no centro de massa da imagem.
#
# <details>
# <summary>
#     <font size="3" color="darkblue"><b>Dicas:</b></font>
# </summary>
#
# * Mostre o *plote* da assinatura com "pontos". Veja o exemplo abaixo.
#
# * Para colocar um '+' no centro de massa, utilize um `plt.plot` após mostrar a imagem.
#
# *Ex:*
# ``` python
# # Fazer um plot sem ligar os pontos. Colocando um ponto (.) em cada par de coordenada
# plt.plot(x, y,'.')
# # Mostra a imagem
# plt.imshow(myImg, 'gray')
# # Coloca um '+' no centro de massa
# plt.plot(ic, jc, '+')
# ```

# %%
def assinatura(img, ic, jc):
  '''
  Descrição: Cria assinatura para uma imagem.

  Entrada:
    - img: Imagem de entrada (uint8).
    - ic: Coordenada X do centro de massa normalizado (uint8).
    - jc: Coordenada Y do centro de massa normalizado (uint8).
  
  Saída:
    - rho: Coordenadas polar (rho) dos pontos [range=0:img.shape[0]*np.sqrt(2)/2].
    - theta: Coordenadas polar (theta) dos pontos [range=-180:180].
  '''
  # Sistema de coordenadas
  # .__> jj (y)
  # |   
  # v
  # ii (x)

  # Teste de insanidade
  if img.ndim != 2:
    raise ValueError('Imagem deve ter 2 dimensões.')

  # Varre a imagem, determinando as coordenadas dos pontos brancos
  ii,jj = np.nonzero(img)

  # Translada a origem do sistema de coordenadas para o centro de massa
  ii -= np.int(ic)
  jj -= np.int(jc)

  # Converte as novas coordenadas cartesianas para coordenadas polares
  rho = np.sqrt(ii**2 + jj**2)
  theta = np.rad2deg(np.arctan2(jj, ii))

  return rho, theta

## -- Seu código começa AQUI -- ##

## -- Seu código termina AQUI -- ##

# %% [markdown]
# ### 4) *Local Binnary Patterns* (LBP)
#
# <center><figure class="half" style="display:flex">
#     <img width="200" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/tex1.png">
#     <img width="200" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/tex2.png">
#     <img width="200" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/tex3.png">
#     <img width="200" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/tex4.png">
#     <figcaption><b> Figura 4: </b> Da esquerda para a direita: feijão, macarrão, arroz e arroz novamente.</figcaption>
# </figure></center>
#
# **Exercício:**
#
# 1. Calcule os mapas de textura por padrões binários locais (LBP) das imagens apresentadas anteriormente. Cada uma representa a imagem de um alimento (feijão, macarrão, arroz). Considere raio 1 e 8 vizinhos, e utilize o método por 'default': LBP circular original;
#
# 2. Apresente os mapas de texturas calculados (imagens) e o histograma correpondente a cada um;
#
# 3. Carregue a imagem `tex4.tiff`, e também apresente o seu mapa de textura e o seu histograma LBP. Calcule a distância euclidiana entre os histogramas LBP de cada imagem e o histograma da imagem `tex4.tiff`. A distância euclidiana nesse caso está sendo utilizada como métrica de similaridade. De acordo com a menor distância entre os histogramas (maior similaridade), classifique a qual dos três tipos de textura a imagem `tex4.tiff` pertence;
#
# 4. Varie o raio, o número de pontos e o método utilizado para o 'rot': versão que lida com variação da rotação; e verifique como a distância entre os histogramas varia, se desrevem melhor as amostras da mesma classe.
#
# <details>
# <summary>
#    <font size="3" color="darkblue"><b>Dicas:</b></font>
# </summary>
#
# *  Você pode utilizar a função [local_binary_pattern](https://scikit-image.org/docs/dev/api/skimage.feature.html?highlight=lbp#skimage.feature.local_binary_pattern) da biblioteca `scikit-image.feature` para calcular o LBP.
#
# * Você pode utilizar a função [np.linalg.norm](https://numpy.org/doc/stable/reference/generated/numpy.linalg.norm.html) da biblioteca `numpy.linalg` para calcular a distância entre os vetores.
#
# *Ex:*
# ``` python
# # P correspondendo aos pontos e R ao raio.
# image_LBP = local_binary_pattern(myImg, P, R, method='default')
#
# L2_distance = np.linalg.norm(vetor_diferenca_entre_histogramas)
# ```

# %%
## -- Seu código começa AQUI -- ##

## -- Seu código termina AQUI -- ##

# %% [markdown]
# ### 5) Descritor de cor
#
# Esse exercício tem como objetivo obter um descritor sobre os pontos de ferrugem nas folhas de café.
#
# <center><img src="https://github.com/LAVI-USP/SEL0339-SEL5886_2021/raw/main/imagens/pratica_09/folha_ruim.png" width="242" height="512"></center>
#
# <center><caption><b> Figura 5:</b> folha_ruim.png.</b></caption></center>
#
#
# **Exercício:**
#
# 1. Extraia os canais R, G e B da imagem `folha_ruim.png`;
#
# 2. Como a ferrugem possui pigmentação amarelada, os canais R e G possuirão altos valores de intensidade nos pontos de ferrugem enquanto que o canal B terá baixos valores de intensidade. Faça o que se pede:
#
#   *   Criar uma máscara binária $M(x)$ para os canais R e G em tal que:
#
#   \begin{equation}
#   M(x) =
#   \left\{\begin{matrix}
#   P(x) >= 200, \;\;\;1
#   \\
#   P(x)\,\,<\,\, 200, \;\;\;0
#   \end{matrix}\right.
#   \end{equation}
#
#   *   Criar uma máscara binária $M(x)$ para o canal B em que:
#
#   \begin{equation}
#   M(x) =
#   \left\{\begin{matrix}
#   P(x) <= 100, \;\;\;1
#   \\
#   P(x)\,\,>\,\, 100, \;\;\;0
#   \end{matrix}\right.
#   \end{equation}
#
# 3. Mostre a matriz binária gerada resultada da multiplicação das três máscaras (R, G e B) e comente sobre os pontos encontrados;
#
# 4. Faça um descritor para a relação entre pixel de ferrugem $P_{fr}$ e pixel de folha $P_{fl}$:
#
#   \begin{equation}
#   Cor_{\gamma}(\%) = \frac{P_{fr}}{P_{fl}}
#   \end{equation}

# %%
## -- Seu código começa AQUI -- ##

## -- Seu código termina AQUI -- ##
